# %%
username="admin"
password="1234"

if username== "admin" and password=="1234":
   print("login successfull")
else:
  print("Invalid Credentials")
# Out:
# login successfull

# %%
marks = [45, 78, 90, 33, 60]
p_count=0
f_count=0
for m in marks:
  if m >=50:
    p_count+=1
  else:
    f_count+=1
print(f"Total pass studentds:{p_count}")
print(f"Total fail studentds:{f_count}")
# Out:
# Total pass studentds:3
# Total fail studentds:2

# %%
messages = ["Hi", "Welcome to the platform", "OK"]
for m in messages:
  print(f"Length of '{m}':{len(m)}")
  if len(m)> 10:
    print(f" ->Flagged:{m} is longer than 10 characters")
# Out:
# Length of 'Hi':2
# Length of 'Welcome to the platform':23
#  ->Flagged:Welcome to the platform is longer than 10 characters
# Length of 'OK':2

# %%
logs = ["INFO", "ERROR", "WARNING", "ERROR"]
error_counts=logs.count("ERROR")
print(f"Total error counts:{error_counts}")
# Out:
# Total error counts:2
